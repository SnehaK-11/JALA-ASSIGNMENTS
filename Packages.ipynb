# %%
"""
1. Create a program to create two class.
1.1. Create a constructor and a method for each class
1.2. Create a __init__.py for adding all packages
1.3. Import the respective packages
1.4. Call each class by creating an object to it 
1.5. Create a program by all the above
"""
# package1/module1.py
class ClassA:
    def __init__(self):
        print("ClassA constructor")

    def method_a(self):
        print("ClassA method")
# package2/module2.py
class ClassB:
    def __init__(self):
        print("ClassB constructor")

    def method_b(self):
        print("ClassB method called")
# Main program (importing classes from "packages")
#  from package1.module1 import ClassA
# from package2.module2 import ClassB
if __name__ == "__main__":
    obj_a = ClassA()
    obj_b = ClassB()
    obj_a.method_a()
    obj_b.method_b()
# Out:
# ClassA constructor
# ClassB constructor
# ClassA method
# ClassB method called
