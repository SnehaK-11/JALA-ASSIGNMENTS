# %%
## Write a program to print your name
print("Sneha Keerthi")
# Out:
# Sneha Keerthi

# %%
## Write a program for a Single line comment and multi-line comments
# This is a single-line comment
print("Single-line comment")
"""
This is a multi-line comment.
which is used to write more than one line
"""
print("Multi-line comment")
# Out:
# Single-line comment
# Multi-line comment

# %%
## Define variables for different Data Types int,Boolean,char,float,double n print on the console
a = 100       ## int        
b = False     ## Boolean   
c = 'K'       ## char
d = 3.14      ## float
e = 14.23     ## double
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 100
# False
# K
# 3.14
# 14.23

# %%
## Define the local and Global variables with the same name and print both variables and understand the scope of the variables
x = 30   # Global variable: Accessed outside the function
def display():
    x = 60   # Local variable: Accessed inside the function
    print("Local variable x:", x)
display()
print("Global variable x:", x)
# Out:
# Local variable x: 60
# Global variable x: 30
