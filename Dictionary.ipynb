# %%
"""1. Create a Dictionary with at least 5 key value pairs of the Student ID and Name
1.1. Adding the values in dictionary
1.2. Updating the values in dictionary
1.3. Accessing the value in dictionary
1.4. Create a nested loop dictionary
1.5. Access the values of nested loop dictionary
1.6. Print the keys present in a particular dictionary
1.7. Delete a value from a dictionary   python# 1. Create a dictionary with at least 5 Student ID and Name pairs
""" 
students = {
    397: "Sneha",
    327: "Keerthi",
    353: "Anjali",
    233: "Priyanka",
    122: "Shruthi"
}
# 1.1 
students[134] = "Divya"
# 1.2
students[327] = "Akshaya"
# 1.3
print("Student with ID 233:", students[233])
# 1.4
student_details = {
    397: {"Name": "Sneha", "Age": 20},
    233: {"Name": "Priyanka", "Age": 21},
    122: {"Name": "Shruthi", "Age": 19}
}
# 1.5
print("Name:", student_details[397]["Name"])
print("Age:", student_details[397]["Age"])
# 1.6 
print("Student IDs:", students.keys())
# 1.7 
del students[122]
# Display final dictionary
print("Final Student Dictionary:", students)
# Out:
# Student with ID 233: Priyanka
# Name: Sneha
# Age: 20
# Student IDs: dict_keys([397, 327, 353, 233, 122, 134])
# Final Student Dictionary: {397: 'Sneha', 327: 'Akshaya', 353: 'Anjali', 233: 'Priyanka', 134: 'Divya'}
